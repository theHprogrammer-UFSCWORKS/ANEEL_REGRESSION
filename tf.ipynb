# %% [markdown]
# #### 1. Carga de um conjunto de dados com um volume de dados adequado para o contexto dadisciplina (+10.000 registros)
#
# ##### Dicionário de dados obtidos em: [ANEEL](https://dadosabertos.aneel.gov.br/dataset/interrupcoes-de-energia-eletrica-nas-redes-de-distribuicao/resource/6e5611de-948d-4473-b309-520d7523b762)
#
# | Informação                                 | Detalhes |
# |--------------------------------------------|----------|
# | **Dicionário Versão:**                     | 1.0      |
# | **Data:**                                  | 11-10-2022 |
# | **E-mail institucional da área responsável** | monitoramento.sfe@aneel.gov.br |
# | **Categorias no VCGE**                     | Energia elétrica |
# | **Palavras-chave do conjunto de dados**    | interrupção, distribuidora, conjuntos elétricos, expurgos, indicadores de continuidade |
# | **Frequência de atualização**              | Mensal   |
#
# ### Detalhamento dos Campos:
#
# | Nome do Campo                       | Tipo do Dado          | Tamanho do Campo | Descrição |
# |-------------------------------------|-----------------------|------------------|-----------|
# | DatGeracaoConjuntoDados             | Data simples          | -                | Data do processamento de carga automática no momento da geração para publicação do conjunto de dados abertos. |
# | IdeConjuntoUnidadeConsumidora       | Numérico              | 10               | Código do conjunto da unidade consumidora. |
# | DscAlimentadorSubestacao            | Cadeia de Caracteres  | 255              | Descrição do alimentador da subestação. |
# | DscSubestacaoDistribuicao           | Cadeia de Caracteres  | 255              | Descrição da subestação de distribuição. |
# | NumOrdemInterrupcao                 | Cadeia de Caracteres  | 255              | Descrição da Ordem de Interrupção. |
# | DscTipoInterrupcao                  | Cadeia de Caracteres  | 14               | Tipos de interrupções existentes. |
# | IdeMotivoExpurgo                    | Numérico              | 2                | Identificador referenciando o Motivo do Expurgo. |
# | DatInicioInterrupcao                | Data Hora             | -                | Data e hora do início da interrupção. |
# | DatFimInterrupcao                   | Data Hora             | -                | Data e hora do reestabelecimento da interrupção. |
# | FatGeradorInterrupcao               | Cadeia de Caracteres  | 255              | Descrição do fato gerador da interrupção. |
# | NumNivelTensao                      | Numérico              | 10               | Nível de tensão onde o fato gerador foi verificado. |
# | NumUnidadeConsumidora               | Numérico              | 10               | Número de unidades consumidoras atingidas. |
# | NumConsumidorConjunto               | Numérico              | 10               | Número de consumidores do conjunto. |
# | NumAno                              | Cadeia de Caracteres  | 4                | Ano de início da Interrupção. |
# | NomAgenteRegulado                   | Cadeia de Caracteres  | 255              | Nome do agente do setor regulado. |
# | SigAgente                           | Cadeia de Caracteres  | 20               | Sigla que abrevia o nome dos Agentes regulados pela ANEEL. |
# | NumCPFCNPJ                          | Cadeia de Caracteres  | 14               | Número do CNPJ ou CPF do agente fiscalizado. |
#
#
# > Identificador referenciando o Motivo do Expurgo.
# >
# > 0 - Não houve expurgo
# >
# > 1 - Falha nas instalações da unidade consumidora que não provoque interrupção em instalações de terceiros
# >
# > 2 - Interrupção decorrente de obras de interesse exclusivo do consumidor e que afete somente a unidade consumidora do mesmo
# >
# > 3 - Interrupção em situação de emergência
# >
# > 4 - Suspensão por inadimplemento do consumidor ou por deficiência técnica e/ou de segurança das instalações da unidade consumidora que não provoque interrupção em instalações de terceiros, previstas em regulamentação
# >
# > 5 - Vinculadas a programas de racionamento instituídos pela União
# >
# > 6 - Ocorridas em dia crítico
# >
# > 7 - Oriundas de atuação de esquemas de alívio de carga solicitado pelo ONS
# >
# > 8 - Interrupção de origem externa ao sistema de distribuição
# >

# %% [markdown]
# ##### Por que escolhemos esse dataset?
#
# A escolha desse dataset para análise focada nos agentes da CELESC baseia-se na relevância estratégica desta empresa no contexto do fornecimento de energia elétrica. A análise promete desdobrar as características intrínsecas das interrupções de energia, possibilitando uma compreensão aprofundada das incidências, suas causas e impactos. Com isso, ele pode identificar padrões e tendências que são fundamentais para aprimorar a gestão e a resposta a interrupções, minimizando o tempo de inatividade e melhorando a satisfação do consumidor.
#
# A importância deste estudo reside na sua capacidade de influenciar positivamente a eficiência operacional. Ao desvendar os tipos de interrupções mais comuns e os motivos de expurgos, ele proporciona uma base de dados sólida para que a CELESC possa implementar medidas preventivas e corretivas mais eficazes.
#
# Para os visualizadores da análise, os insights gerados têm o potencial de elevar a transparência operacional e a confiança. Os consumidores e reguladores poderão observar a proatividade da empresa em lidar com questões críticas e seu compromisso com a melhoria contínua.
#
# Além disso, com a inclusão de uma regressão linear, abre-se a possibilidade de antever situações futuras de interrupções, baseando-se nas variáveis históricas do dataset. Esta modelagem preditiva poderia ser uma ferramenta valiosa para planejamento e alocação de recursos, levando a uma resposta mais ágil em eventos de interrupção e, em última instância, a um fornecimento de energia mais estável e confiável.

# %% [markdown]
# ##### O que podemos obter com esse dataset?
#
# 1. Tipos de Interrupção:
#     - Categorizar e analisar os diferentes tipos de interrupções reportadas.
#
# 2. Duração das Interrupções:
#     - Calcular a duração média das interrupções e identificar as de maior impacto.
#
# 3. Análise Temporal:
#     - Observar tendências ao longo do tempo para identificar padrões sazonais ou anuais de interrupções.
#
# 4. Impacto no Consumidor:
#     - Avaliar o número de unidades consumidoras afetadas por interrupções e o tempo médio de restabelecimento do serviço.
#
# 5. Correlação entre Motivo de Expurgo e Interrupções:
#     - Investigar a relação entre os motivos de expurgo e os fatos geradores de interrupções.
#
# 6. Relação entre Nível de Tensão e Interrupções:
#     - Estudar como diferentes níveis de tensão estão relacionados com a frequência e duração das interrupções.
#
# 7. Identificação de Pontos Críticos:
#     - Localizar áreas geográficas ou alimentadores específicos que apresentam maior número de falhas.
#
# 8. Previsão de Interrupções:
#     - Utilizar regressão linear para prever futuras interrupções com base em padrões históricos.
#
# 9. Avaliação de Conformidade?
#     - Checar a conformidade dos dados com as normativas e diretrizes da ANEEL.

# %%
# Bibliotecas
#import requests
#from concurrent.futures import ThreadPoolExecutor

import pandas as pd
import numpy as np
from datetime import datetime as dt
import holidays
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn import metrics
import warnings
warnings.filterwarnings('ignore')

# %%
'''
def fetch_data(url):
    """
    Faz uma requisição GET para a URL fornecida, carrega os dados e retorna os registros e a próxima URL.

    :param url: URL para fazer a requisição
    :return: Uma tupla contendo uma lista de registros e a próxima URL
    """
    try:
        # Faz a requisição para a URL
        response = requests.get(url)
        # Checa se a resposta HTTP foi bem-sucedida (status 200)
        response.raise_for_status()
        
        # Carrega os dados JSON da resposta
        data = response.json()
        # Extrai os registros da resposta
        records = data['result']['records']
        
        # Verifica se existe uma próxima página e cria a URL correspondente
        next_url = base_url + data['result']['_links']['next'] if 'next' in data['result']['_links'] else None
        
        print(f"Página carregada com sucesso! URL: {url}")
        return records, next_url
    except requests.HTTPError as http_err:
        # Trata erros de resposta HTTP (ex: 404, 500, etc.)
        print(f"HTTP error occurred: {http_err}")
    except Exception as err:
        # Trata outros tipos de erros genéricos
        print(f"An error occurred: {err}")
    return [], None

def load_data(start_url):
    """
    Carrega dados de várias páginas a partir de uma URL inicial até que não haja mais páginas.

    :param start_url: URL da primeira página
    :return: Um DataFrame do Pandas contendo todos os dados carregados
    """
    # Lista para armazenar todos os registros
    data = []
    # Define a próxima URL como a URL de início
    next_url = start_url
    
    # Cria um executor de pool de threads
    with ThreadPoolExecutor() as executor:
        # Enquanto houver uma próxima URL
        while next_url:
            # Carrega os dados da URL atual
            records, next_url = fetch_data(next_url)
            # Adiciona os registros à lista de dados
            data.extend(records)
    
    # Converte a lista de dados em um DataFrame do Pandas
    df = pd.DataFrame(data)
    return df
'''
# Out:
# '\ndef fetch_data(url):\n    """\n    Faz uma requisição GET para a URL fornecida, carrega os dados e retorna os registros e a próxima URL.\n\n    :param url: URL para fazer a requisição\n    :return: Uma tupla contendo uma lista de registros e a próxima URL\n    """\n    try:\n        # Faz a requisição para a URL\n        response = requests.get(url)\n        # Checa se a resposta HTTP foi bem-sucedida (status 200)\n        response.raise_for_status()\n        \n        # Carrega os dados JSON da resposta\n        data = response.json()\n        # Extrai os registros da resposta\n        records = data[\'result\'][\'records\']\n        \n        # Verifica se existe uma próxima página e cria a URL correspondente\n        next_url = base_url + data[\'result\'][\'_links\'][\'next\'] if \'next\' in data[\'result\'][\'_links\'] else None\n        \n        print(f"Página carregada com sucesso! URL: {url}")\n        return records, next_url\n    except requests.HTTPError as http_err:\n        # Trata erros de resposta HTTP (ex: 404, 500, etc.)\n        print(f"HTTP error occurred: {http_err}")\n    except Exception as err:\n        # Trata outros tipos de erros genéricos\n        print(f"An error occurred: {err}")\n    return [], None\n\ndef load_data(start_url):\n    """\n    Carrega dados de várias páginas a partir de uma URL inicial até que não haja mais páginas.\n\n    :param start_url: URL da primeira página\n    :return: Um DataFrame do Pandas contendo todos os dados carregados\n    """\n    # Lista para armazenar todos os registros\n    data = []\n    # Define a próxima URL como a URL de início\n    next_url = start_url\n    \n    # Cria um executor de pool de threads\n    with ThreadPoolExecutor() as executor:\n        # Enquanto houver uma próxima URL\n        while next_url:\n            # Carrega os dados da URL atual\n            records, next_url = fetch_data(next_url)\n            # Adiciona os registros à lista de dados\n            data.extend(records)\n    \n    # Converte a lista de dados em um DataFrame do Pandas\n    df = pd.DataFrame(data)\n    return df\n'

# %%
'''
# URL base da API
base_url = "https://dadosabertos.aneel.gov.br"

# URL da primeira página
start_url = "https://dadosabertos.aneel.gov.br/api/3/action/datastore_search?resource_id=cce72c2b-a4cb-4b98-818f-3ac56bbf2a78&q=CELESC"

# Carrega os dados
df = load_data(start_url)
'''
# Out:
# '\n# URL base da API\nbase_url = "https://dadosabertos.aneel.gov.br"\n\n# URL da primeira página\nstart_url = "https://dadosabertos.aneel.gov.br/api/3/action/datastore_search?resource_id=cce72c2b-a4cb-4b98-818f-3ac56bbf2a78&q=CELESC"\n\n# Carrega os dados\ndf = load_data(start_url)\n'

# %%
'''
# Mostra as primeiras linhas do DataFrame
df
'''
# Out:
# '\n# Mostra as primeiras linhas do DataFrame\ndf\n'

# %%
'''
# Salvar o DataFrame em um arquivo CSV
df.to_csv("aneel.csv", index=False)
'''
# Out:
# '\n# Salvar o DataFrame em um arquivo CSV\ndf.to_csv("aneel.csv", index=False)\n'

# %%
# Carregar o arquivo CSV
df = pd.read_csv("aneel.csv")

df
# Out:
#             _id DatGeracaoConjuntoDados DscConjuntoUnidadeConsumidora  \
# 0       4561642              2023-10-10               ITAJAÍ ITAIPAVA
# 1       4566860              2023-10-10                     FRAIBURGO
# 2       4566452              2023-10-10                         TIMBO
# 3       4566511              2023-10-10                    ITUPORANGA
# 4       4561672              2023-10-10                         SEARA
# ...         ...                     ...                           ...
# 133439  3584843              2023-10-10              Uniao da Vitoria
# 133440  3584844              2023-10-10              Uniao da Vitoria
# 133441  3683467              2023-10-10              Uniao da Vitoria
# 133442  3707309              2023-10-10              Uniao da Vitoria
# 133443  3391704              2023-10-10              Uniao da Vitoria
#
#        DscAlimentadorSubestacao    DscSubestacaoDistribuicao  \
# 0                         IFA04                          IFA
# 1                         CNS01                          CNS
# 2                         TBO05                          TBO
# 3                         IAA08                          IAA
# 4                         SRA04                          SRA
# ...                         ...                          ...
# 133439         729800792-CELESC  72980-Unico da Vitsria(CSL)
# 133440         729800792-CELESC  72980-Unico da Vitsria(CSL)
# 133441         729800792-CELESC  72980-Unico da Vitsria(CSL)
# 133442         729800792-CELESC  72980-Unico da Vitsria(CSL)
# 133443         729800792-CELESC  72980-Unico da Vitsria(CSL)
#
#        NumOrdemInterrupcao DscTipoInterrupcao  IdeMotivoInterrupcao  \
# 0               27226519/0     Não Programada                     0
# 1               27282537/0     Não Programada                     0
# 2               27277948/0     Não Programada                     0
# 3               27278496/0     Não Programada                     0
# 4               27222410/0     Não Programada                     0
# ...                    ...                ...                   ...
# 133439    1011760047-15927     Não Programada                     0
# 133440    1011760048-15927     Não Programada                     0
# 133441    1011776778-15927     Não Programada                     8
# 133442    1011780791-15927     Não Programada                     0
# 133443    1011728841-15927     Não Programada                     0
#
#        DatInicioInterrupcao    DatFimInterrupcao  \
# 0       2023-01-02 21:20:00  2023-01-03 00:02:00
# 1       2023-01-12 18:29:00  2023-01-12 21:32:00
# 2       2023-01-12 09:24:00  2023-01-12 10:37:00
# 3       2023-01-12 10:50:00  2023-01-12 13:25:00
# 4       2023-01-03 00:59:00  2023-01-03 08:50:00
# ...                     ...                  ...
# 133439  2023-06-14 01:22:00  2023-06-14 01:22:00
# 133440  2023-06-14 01:28:00  2023-06-14 01:28:00
# 133441  2023-08-15 08:30:00  2023-08-15 10:46:00
# 133442  2023-08-27 06:15:00  2023-08-27 06:16:00
# 133443  2023-02-09 14:49:00  2023-02-09 14:49:00
#
#                                 DscFatoGeradorInterrupcao  NumNivelTensao  \
# 0       Interna/Nao Programada/Proprias do Sistema/Sob...             220
# 1                 Interna/Nao Programada/Nao Classificada             220
# 2                 Interna/Nao Programada/Nao Classificada             220
# 3                 Interna/Nao Programada/Nao Classificada             220
# 4                 Interna/Nao Programada/Nao Classificada           23000
# ...                                                   ...             ...
# 133439  INTERNA-NAO PROGRAMADA-PROPRIAS DO SISTEMA-NAO...           34500
# 133440  INTERNA-NAO PROGRAMADA-PROPRIAS DO SISTEMA-NAO...           34500
# 133441            EXTERNA-NAO PROGRAMADA-NAO CLASSIFICADA          230000
# 133442  INTERNA-NAO PROGRAMADA-PROPRIAS DO SISTEMA-NAO...           34500
# 133443  INTERNA-NAO PROGRAMADA-PROPRIAS DO SISTEMA-NAO...           34500
#
#         NumUnidadeConsumidora  NumConsumidorConjunto  NumAno  \
# 0                          94                  50565    2023
# 1                           1                  22850    2023
# 2                           1                  40933    2023
# 3                           1                  26693    2023
# 4                          43                  14119    2023
# ...                       ...                    ...     ...
# 133439                      1                  33248    2023
# 133440                      1                  33248    2023
# 133441                      1                  33323    2023
# 133442                      1                  33323    2023
# 133443                      1                  33189    2023
#
#               NomAgenteRegulado             SigAgente     NumCPFCNPJ      rank
# 0       CELESC DISTRIBUIÇÃO S.A  CELESC-DIS            8336783000190  0.070624
# 1       CELESC DISTRIBUIÇÃO S.A  CELESC-DIS            8336783000190  0.070624
# 2       CELESC DISTRIBUIÇÃO S.A  CELESC-DIS            8336783000190  0.070624
# 3       CELESC DISTRIBUIÇÃO S.A  CELESC-DIS            8336783000190  0.070624
# 4       CELESC DISTRIBUIÇÃO S.A  CELESC-DIS            8336783000190  0.070624
# ...                         ...                   ...            ...       ...
# 133439  COPEL DISTRIBUIÇÃO S.A.  COPEL-DIS             4368898000106  0.057309
# 133440  COPEL DISTRIBUIÇÃO S.A.  COPEL-DIS             4368898000106  0.057309
# 133441  COPEL DISTRIBUIÇÃO S.A.  COPEL-DIS             4368898000106  0.057309
# 133442  COPEL DISTRIBUIÇÃO S.A.  COPEL-DIS             4368898000106  0.057309
# 133443  COPEL DISTRIBUIÇÃO S.A.  COPEL-DIS             4368898000106  0.057309
#
# [133444 rows x 19 columns]

# %% [markdown]
# #### 2. Realização do pré-processamento sobre o conjunto de dados

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133444 entries, 0 to 133443
# Data columns (total 19 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   _id                            133444 non-null  int64
#  1   DatGeracaoConjuntoDados        133444 non-null  object
#  2   DscConjuntoUnidadeConsumidora  133444 non-null  object
#  3   DscAlimentadorSubestacao       133444 non-null  object
#  4   DscSubestacaoDistribuicao      133444 non-null  object
#  5   NumOrdemInterrupcao            133444 non-null  object
#  6   DscTipoInterrupcao             133444 non-null  object
#  7   IdeMotivoInterrupcao           133444 non-null  int64
#  8   DatInicioInterrupcao           133444 non-null  object
#  9   DatFimInterrupcao              133444 non-null  object
#  10  DscFatoGeradorInterrupcao      133444 non-null  object
#  11  NumNivelTensao                 133444 non-null  int64
#  12  NumUnidadeConsumidora          133444 non-null  int64
#  13  NumConsumidorConjunto          133444 non-null  int64
#  14  NumAno                         133444 non-null  int64
#  15  NomAgenteRegulado              133444 non-null  object
#  16  SigAgente                      133444 non-null  object
#  17  NumCPFCNPJ                     133444 non-null  int64
#  18  rank                           133444 non-null  float64
# dtypes: float64(1), int64(7), object(11)
# memory usage: 19.3+ MB

# %%
# Copiar o DataFrame para um DataFrame de análise
df_analise = df.copy()

# Verifica se a coluna _id é única
print(f"Coluna _id é única? {df_analise['_id'].is_unique}")

# Verifica se tem valores duplicados
print(f"Tem valores duplicados? {df_analise.duplicated().any()}")

# Mostra a quantidade de valores duplicados
if df_analise.duplicated().any():
    print(f"Quantidade de valores duplicados: {df_analise.duplicated().sum()} \n")
    # Mostra as linhas duplicadas
    print("Linhas duplicadas:")
    display(df_analise[df_analise.duplicated(keep=False)].sort_values(by=['_id']))
# Out:
# Coluna _id é única? False
# Tem valores duplicados? True
# Quantidade de valores duplicados: 102
#
# Linhas duplicadas:
#           _id DatGeracaoConjuntoDados DscConjuntoUnidadeConsumidora  \
# 305   4560861              2023-10-10                JARAGUÁ DO SUL
# 299   4560861              2023-10-10                JARAGUÁ DO SUL
# 799   4561143              2023-10-10                    CHAPECÓ II
# 805   4561143              2023-10-10                    CHAPECÓ II
# 899   4561256              2023-10-10                 RIO DO SUL II
# ...       ...                     ...                           ...
# 9607  4570201              2023-10-10                   SAO JOAQUIM
# 399   4579164              2023-10-10                      ARAQUARI
# 405   4579164              2023-10-10                      ARAQUARI
# 705   4591917              2023-10-10                       INDAIAL
# 699   4591917              2023-10-10                       INDAIAL
#
#      DscAlimentadorSubestacao DscSubestacaoDistribuicao NumOrdemInterrupcao  \
# 305                     JSL11                       JSL          27213144/0
# 299                     JSL11                       JSL          27213144/0
# 799                     CCI11                       CCI          27215868/0
# 805                     CCI11                       CCI          27215868/0
# 899                     RSD08                       RSD          27216746/0
# ...                       ...                       ...                 ...
# 9607                    SJM05                       SJM          27321189/0
# 399                     ARI05                       ARI          27241113/1
# 405                     ARI05                       ARI          27241113/1
# 705                     IAL02                       IAL          22104096/1
# 699                     IAL02                       IAL          22104096/1
#
#      DscTipoInterrupcao  IdeMotivoInterrupcao DatInicioInterrupcao  \
# 305      Não Programada                     0  2023-01-01 08:05:00
# 299      Não Programada                     0  2023-01-01 08:05:00
# 799      Não Programada                     0  2023-01-02 06:36:00
# 805      Não Programada                     0  2023-01-02 06:36:00
# 899      Não Programada                     0  2023-01-02 09:17:00
# ...                 ...                   ...                  ...
# 9607     Não Programada                     0  2023-01-16 17:44:00
# 399          Programada                     0  2023-01-30 08:30:00
# 405          Programada                     0  2023-01-30 08:30:00
# 705          Programada                     0  2023-02-22 13:00:00
# 699          Programada                     0  2023-02-22 13:00:00
#
#         DatFimInterrupcao                          DscFatoGeradorInterrupcao  \
# 305   2023-01-01 08:11:00      Interna/Nao Programada/Terceiros/Abalroamento
# 299   2023-01-01 08:11:00      Interna/Nao Programada/Terceiros/Abalroamento
# 799   2023-01-02 09:09:00  Interna/Nao Programada/Meio Ambiente/Descarga ...
# 805   2023-01-02 09:09:00  Interna/Nao Programada/Meio Ambiente/Descarga ...
# 899   2023-01-02 10:05:00  Interna/Nao Programada/Meio Ambiente/Arvore ou...
# ...                   ...                                                ...
# 9607  2023-01-16 20:40:00  Interna/Nao Programada/Meio Ambiente/Arvore ou...
# 399   2023-01-30 12:20:00            Interna/Programada/Manutencao/Corretiva
# 405   2023-01-30 12:20:00            Interna/Programada/Manutencao/Corretiva
# 705   2023-02-22 16:40:00         Interna/Programada/Alteracao/Para Melhoria
# 699   2023-02-22 16:40:00         Interna/Programada/Alteracao/Para Melhoria
#
#       NumNivelTensao  NumUnidadeConsumidora  NumConsumidorConjunto  NumAno  \
# 305              220                    275                  42718    2023
# 299              220                    275                  42718    2023
# 799            23000                     64                  72361    2023
# 805            23000                     64                  72361    2023
# 899              220                     26                  26240    2023
# ...              ...                    ...                    ...     ...
# 9607           23000                      5                  14737    2023
# 399              220                     27                  29816    2023
# 405              220                     27                  29816    2023
# 705              220                     26                  30856    2023
# 699              220                     26                  30856    2023
#
#             NomAgenteRegulado             SigAgente     NumCPFCNPJ      rank
# 305   CELESC DISTRIBUIÇÃO S.A  CELESC-DIS            8336783000190  0.070624
# 299   CELESC DISTRIBUIÇÃO S.A  CELESC-DIS            8336783000190  0.070624
# 799   CELESC DISTRIBUIÇÃO S.A  CELESC-DIS            8336783000190  0.070624
# 805   CELESC DISTRIBUIÇÃO S.A  CELESC-DIS            8336783000190  0.070624
# 899   CELESC DISTRIBUIÇÃO S.A  CELESC-DIS            8336783000190  0.070624
# ...                       ...                   ...            ...       ...
# 9607  CELESC DISTRIBUIÇÃO S.A  CELESC-DIS            8336783000190  0.070624
# 399   CELESC DISTRIBUIÇÃO S.A  CELESC-DIS            8336783000190  0.070624
# 405   CELESC DISTRIBUIÇÃO S.A  CELESC-DIS            8336783000190  0.070624
# 705   CELESC DISTRIBUIÇÃO S.A  CELESC-DIS            8336783000190  0.070624
# 699   CELESC DISTRIBUIÇÃO S.A  CELESC-DIS            8336783000190  0.070624
#
# [204 rows x 19 columns]

# %%
# Remover linhas duplicadas
df_analise.drop_duplicates(inplace=True)

# Verifica se tem valores duplicados
print(f"Tem valores duplicados? {df_analise.duplicated().any()}")
# Out:
# Tem valores duplicados? False

# %%
# Remover colunas que não serão utilizadas
drop = ['_id', 'DatGeracaoConjuntoDados', 'NumOrdemInterrupcao', 'NumAno', 'NomAgenteRegulado', 'NumCPFCNPJ', 'rank']
df_analise.drop(drop, axis=1, inplace=True)

# Indice de colunas
df_analise.columns
# Out:
# Index(['DscConjuntoUnidadeConsumidora', 'DscAlimentadorSubestacao',
#        'DscSubestacaoDistribuicao', 'DscTipoInterrupcao',
#        'IdeMotivoInterrupcao', 'DatInicioInterrupcao', 'DatFimInterrupcao',
#        'DscFatoGeradorInterrupcao', 'NumNivelTensao', 'NumUnidadeConsumidora',
#        'NumConsumidorConjunto', 'SigAgente'],
#       dtype='object')

# %%
# Remover Agentes que não são da CELESC
df_analise = df_analise[df_analise['SigAgente'].str.contains("CELESC")]

# Mostrar a quantidade de registros
print(f"Quantidade de registros: {df_analise.shape[0]}")
print(f"Agentes: {df_analise['SigAgente'].unique()}")
# Out:
# Quantidade de registros: 133335
# Agentes: ['CELESC-DIS          ']

# %%
df_analise.head()
# Out:
#   DscConjuntoUnidadeConsumidora DscAlimentadorSubestacao  \
# 0               ITAJAÍ ITAIPAVA                    IFA04
# 1                     FRAIBURGO                    CNS01
# 2                         TIMBO                    TBO05
# 3                    ITUPORANGA                    IAA08
# 4                         SEARA                    SRA04
#
#   DscSubestacaoDistribuicao DscTipoInterrupcao  IdeMotivoInterrupcao  \
# 0                       IFA     Não Programada                     0
# 1                       CNS     Não Programada                     0
# 2                       TBO     Não Programada                     0
# 3                       IAA     Não Programada                     0
# 4                       SRA     Não Programada                     0
#
#   DatInicioInterrupcao    DatFimInterrupcao  \
# 0  2023-01-02 21:20:00  2023-01-03 00:02:00
# 1  2023-01-12 18:29:00  2023-01-12 21:32:00
# 2  2023-01-12 09:24:00  2023-01-12 10:37:00
# 3  2023-01-12 10:50:00  2023-01-12 13:25:00
# 4  2023-01-03 00:59:00  2023-01-03 08:50:00
#
#                            DscFatoGeradorInterrupcao  NumNivelTensao  \
# 0  Interna/Nao Programada/Proprias do Sistema/Sob...             220
# 1            Interna/Nao Programada/Nao Classificada             220
# 2            Interna/Nao Programada/Nao Classificada             220
# 3            Interna/Nao Programada/Nao Classificada             220
# 4            Interna/Nao Programada/Nao Classificada           23000
#
#    NumUnidadeConsumidora  NumConsumidorConjunto             SigAgente
# 0                     94                  50565  CELESC-DIS
# 1                      1                  22850  CELESC-DIS
# 2                      1                  40933  CELESC-DIS
# 3                      1                  26693  CELESC-DIS
# 4                     43                  14119  CELESC-DIS

# %%
# Verificar se tem valores nulos
print(f"Tem valores nulos? {df_analise.isnull().values.any()}")
# Out:
# Tem valores nulos? False

# %%
# Mostrar lista de valores em DscFatoGeradorInterrupcao
print("Valores em DscFatoGeradorInterrupcao:")
display(df_analise['DscFatoGeradorInterrupcao'].unique())
# Out:
# Valores em DscFatoGeradorInterrupcao:
# array(['Interna/Nao Programada/Proprias do Sistema/Sobrecarga',
#        'Interna/Nao Programada/Nao Classificada',
#        'Interna/Nao Programada/Meio Ambiente/Arvore ou Vegetacao',
#        'Interna/Programada/Alteracao/Para Ampliacao',
#        'Interna/Nao Programada/Meio Ambiente/Animais',
#        'Interna/Programada/Manutencao/Preventiva',
#        'Interna/Nao Programada/Meio Ambiente/Descarga Atmosferica',
#        'Interna/Nao Programada/Proprias do Sistema/Nao identificada',
#        'Interna/Nao Programada/Meio Ambiente/Vento',
#        'Interna/Nao Programada/Terceiros/Roubo',
#        'Interna/Programada/Manutencao/Corretiva',
#        'Interna/Programada/Alteracao/Para Melhoria',
#        'Interna/Nao Programada',
#        'Interna/Nao Programada/Terceiros/Objeto na Rede',
#        'Interna/Nao Programada/Terceiros/Abalroamento',
#        'Interna/Nao Programada/Proprias do Sistema/Falha de material ou equipamento',
#        'Interna/Nao Programada/Terceiros/Defeito interno nao afetando outras unidades consumidoras',
#        'Externa/Nao Programada',
#        'Interna/Nao Programada/Falha Operacional/Erro de Operacao',
#        'Interna/Nao Programada/Proprias do Sistema/Subtensao',
#        'Interna/Nao Programada/Meio Ambiente/Poluicao',
#        'Interna/Nao Programada/Proprias do Sistema/Desligamento para manutencao emergencial',
#        'Interna/Nao Programada/Terceiros/Defeito Cliente Afetando Outros',
#        'Externa/Programada'], dtype=object)

# %%
# Separar os valores da coluna DscFatoGeradorInterrupcao
df_analise[['DscInterrupcaoOrigem', 'DscInterrupcaoTipo', 'DscInterrupcaoCausa', 'DscInterrupcaoDescricao']] = df_analise['DscFatoGeradorInterrupcao'].str.split("/", expand=True)

df_analise.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 133335 entries, 0 to 133436
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   DscConjuntoUnidadeConsumidora  133335 non-null  object
#  1   DscAlimentadorSubestacao       133335 non-null  object
#  2   DscSubestacaoDistribuicao      133335 non-null  object
#  3   DscTipoInterrupcao             133335 non-null  object
#  4   IdeMotivoInterrupcao           133335 non-null  int64
#  5   DatInicioInterrupcao           133335 non-null  object
#  6   DatFimInterrupcao              133335 non-null  object
#  7   DscFatoGeradorInterrupcao      133335 non-null  object
#  8   NumNivelTensao                 133335 non-null  int64
#  9   NumUnidadeConsumidora          133335 non-null  int64
#  10  NumConsumidorConjunto          133335 non-null  int64
#  11  SigAgente                      133335 non-null  object
#  12  DscInterrupcaoOrigem           133335 non-null  object
#  13  DscInterrupcaoTipo             133335 non-null  object
#  14  DscInterrupcaoCausa            132632 non-null  object
#  15  DscInterrupcaoDescricao        103934 non-null  object
# dtypes: int64(4), object(12)
# memory usage: 17.3+ MB

# %%
# Valores nulos em DscInterrupcaocausa e DscInterrupcaoDescricao, filtrar para Não Classificado (fillna)
df_analise['DscInterrupcaoCausa'].fillna("Nao Classificada", inplace=True)
df_analise['DscInterrupcaoDescricao'].fillna("Nao Classificada", inplace=True)

# Remover a coluna DscFatoGeradorInterrupcao
df_analise.drop('DscFatoGeradorInterrupcao', axis=1, inplace=True)

df_analise.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 133335 entries, 0 to 133436
# Data columns (total 15 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   DscConjuntoUnidadeConsumidora  133335 non-null  object
#  1   DscAlimentadorSubestacao       133335 non-null  object
#  2   DscSubestacaoDistribuicao      133335 non-null  object
#  3   DscTipoInterrupcao             133335 non-null  object
#  4   IdeMotivoInterrupcao           133335 non-null  int64
#  5   DatInicioInterrupcao           133335 non-null  object
#  6   DatFimInterrupcao              133335 non-null  object
#  7   NumNivelTensao                 133335 non-null  int64
#  8   NumUnidadeConsumidora          133335 non-null  int64
#  9   NumConsumidorConjunto          133335 non-null  int64
#  10  SigAgente                      133335 non-null  object
#  11  DscInterrupcaoOrigem           133335 non-null  object
#  12  DscInterrupcaoTipo             133335 non-null  object
#  13  DscInterrupcaoCausa            133335 non-null  object
#  14  DscInterrupcaoDescricao        133335 non-null  object
# dtypes: int64(4), object(11)
# memory usage: 16.3+ MB

# %%
# Mudar todos e tudo o que contem "Nao" para "Não"
df_analise.replace(to_replace="Não Programada", value="Nao programada", inplace=True) 
df_analise.replace(to_replace="Não Classificada", value="Nao classificada", inplace=True)
df_analise.replace(to_replace="Não Informada", value="Nao informada", inplace=True)
df_analise.replace(to_replace="Não Identificada", value="Nao identificada", inplace=True)

# %%
# Remover DscTipoInterrupcao
df_analise.drop('DscTipoInterrupcao', axis=1, inplace=True)

# %%
# Criar uma nova coluna chamada DatSemana contendo se a DatInicioInterrupcao é 'Dia de semana' ou 'Fim de semana'
df_analise['DatSemana'] = np.where(pd.to_datetime(df_analise['DatInicioInterrupcao']).dt.dayofweek < 5, 'Dia de semana', 'Fim de semana')

df_analise.head()
# Out:
#   DscConjuntoUnidadeConsumidora DscAlimentadorSubestacao  \
# 0               ITAJAÍ ITAIPAVA                    IFA04
# 1                     FRAIBURGO                    CNS01
# 2                         TIMBO                    TBO05
# 3                    ITUPORANGA                    IAA08
# 4                         SEARA                    SRA04
#
#   DscSubestacaoDistribuicao  IdeMotivoInterrupcao DatInicioInterrupcao  \
# 0                       IFA                     0  2023-01-02 21:20:00
# 1                       CNS                     0  2023-01-12 18:29:00
# 2                       TBO                     0  2023-01-12 09:24:00
# 3                       IAA                     0  2023-01-12 10:50:00
# 4                       SRA                     0  2023-01-03 00:59:00
#
#      DatFimInterrupcao  NumNivelTensao  NumUnidadeConsumidora  \
# 0  2023-01-03 00:02:00             220                     94
# 1  2023-01-12 21:32:00             220                      1
# 2  2023-01-12 10:37:00             220                      1
# 3  2023-01-12 13:25:00             220                      1
# 4  2023-01-03 08:50:00           23000                     43
#
#    NumConsumidorConjunto             SigAgente DscInterrupcaoOrigem  \
# 0                  50565  CELESC-DIS                        Interna
# 1                  22850  CELESC-DIS                        Interna
# 2                  40933  CELESC-DIS                        Interna
# 3                  26693  CELESC-DIS                        Interna
# 4                  14119  CELESC-DIS                        Interna
#
#   DscInterrupcaoTipo  DscInterrupcaoCausa DscInterrupcaoDescricao  \
# 0     Nao Programada  Proprias do Sistema              Sobrecarga
# 1     Nao Programada     Nao Classificada        Nao Classificada
# 2     Nao Programada     Nao Classificada        Nao Classificada
# 3     Nao Programada     Nao Classificada        Nao Classificada
# 4     Nao Programada     Nao Classificada        Nao Classificada
#
#        DatSemana
# 0  Dia de semana
# 1  Dia de semana
# 2  Dia de semana
# 3  Dia de semana
# 4  Dia de semana

# %%
# Criar uma nova coluna chamada DatFeriado contedo False ou True se a DatInicioInterrupcao é feriado ou não
holiday_list = []
for holiday in holidays.Brazil(years=[2023]).items():
    holiday_list.append(holiday)
    
holidays_df = pd.DataFrame(holiday_list, columns=["date", "holiday"])
pd.to_datetime(holidays_df['date'])

df_analise['DatFeriado'] = np.where(pd.to_datetime(df_analise['DatInicioInterrupcao']).dt.date.isin(holidays_df['date']), True, False)

df_analise.head()
# Out:
#   DscConjuntoUnidadeConsumidora DscAlimentadorSubestacao  \
# 0               ITAJAÍ ITAIPAVA                    IFA04
# 1                     FRAIBURGO                    CNS01
# 2                         TIMBO                    TBO05
# 3                    ITUPORANGA                    IAA08
# 4                         SEARA                    SRA04
#
#   DscSubestacaoDistribuicao  IdeMotivoInterrupcao DatInicioInterrupcao  \
# 0                       IFA                     0  2023-01-02 21:20:00
# 1                       CNS                     0  2023-01-12 18:29:00
# 2                       TBO                     0  2023-01-12 09:24:00
# 3                       IAA                     0  2023-01-12 10:50:00
# 4                       SRA                     0  2023-01-03 00:59:00
#
#      DatFimInterrupcao  NumNivelTensao  NumUnidadeConsumidora  \
# 0  2023-01-03 00:02:00             220                     94
# 1  2023-01-12 21:32:00             220                      1
# 2  2023-01-12 10:37:00             220                      1
# 3  2023-01-12 13:25:00             220                      1
# 4  2023-01-03 08:50:00           23000                     43
#
#    NumConsumidorConjunto             SigAgente DscInterrupcaoOrigem  \
# 0                  50565  CELESC-DIS                        Interna
# 1                  22850  CELESC-DIS                        Interna
# 2                  40933  CELESC-DIS                        Interna
# 3                  26693  CELESC-DIS                        Interna
# 4                  14119  CELESC-DIS                        Interna
#
#   DscInterrupcaoTipo  DscInterrupcaoCausa DscInterrupcaoDescricao  \
# 0     Nao Programada  Proprias do Sistema              Sobrecarga
# 1     Nao Programada     Nao Classificada        Nao Classificada
# 2     Nao Programada     Nao Classificada        Nao Classificada
# 3     Nao Programada     Nao Classificada        Nao Classificada
# 4     Nao Programada     Nao Classificada        Nao Classificada
#
#        DatSemana  DatFeriado
# 0  Dia de semana       False
# 1  Dia de semana       False
# 2  Dia de semana       False
# 3  Dia de semana       False
# 4  Dia de semana       False

# %%
# Cálculo do tempo total de interrupção em minutos
df_analise['TempoTotalInterrupcao'] = (pd.to_datetime(df_analise['DatFimInterrupcao']) - pd.to_datetime(df_analise['DatInicioInterrupcao'])).dt.total_seconds() / 60

df_analise.head()
# Out:
#   DscConjuntoUnidadeConsumidora DscAlimentadorSubestacao  \
# 0               ITAJAÍ ITAIPAVA                    IFA04
# 1                     FRAIBURGO                    CNS01
# 2                         TIMBO                    TBO05
# 3                    ITUPORANGA                    IAA08
# 4                         SEARA                    SRA04
#
#   DscSubestacaoDistribuicao  IdeMotivoInterrupcao DatInicioInterrupcao  \
# 0                       IFA                     0  2023-01-02 21:20:00
# 1                       CNS                     0  2023-01-12 18:29:00
# 2                       TBO                     0  2023-01-12 09:24:00
# 3                       IAA                     0  2023-01-12 10:50:00
# 4                       SRA                     0  2023-01-03 00:59:00
#
#      DatFimInterrupcao  NumNivelTensao  NumUnidadeConsumidora  \
# 0  2023-01-03 00:02:00             220                     94
# 1  2023-01-12 21:32:00             220                      1
# 2  2023-01-12 10:37:00             220                      1
# 3  2023-01-12 13:25:00             220                      1
# 4  2023-01-03 08:50:00           23000                     43
#
#    NumConsumidorConjunto             SigAgente DscInterrupcaoOrigem  \
# 0                  50565  CELESC-DIS                        Interna
# 1                  22850  CELESC-DIS                        Interna
# 2                  40933  CELESC-DIS                        Interna
# 3                  26693  CELESC-DIS                        Interna
# 4                  14119  CELESC-DIS                        Interna
#
#   DscInterrupcaoTipo  DscInterrupcaoCausa DscInterrupcaoDescricao  \
# 0     Nao Programada  Proprias do Sistema              Sobrecarga
# 1     Nao Programada     Nao Classificada        Nao Classificada
# 2     Nao Programada     Nao Classificada        Nao Classificada
# 3     Nao Programada     Nao Classificada        Nao Classificada
# 4     Nao Programada     Nao Classificada        Nao Classificada
#
#        DatSemana  DatFeriado  TempoTotalInterrupcao
# 0  Dia de semana       False                  162.0
# 1  Dia de semana       False                  183.0
# 2  Dia de semana       False                   73.0
# 3  Dia de semana       False                  155.0
# 4  Dia de semana       False                  471.0

# %% [markdown]
# #### 3. A partir do conjunto resultante (pré-processado), estatísticas e visualizações devem ser geradas para promover um entendimento inicial dos dados;

# %%
# 1. Quantidade de interrupções por nível de tensão
# Descrição do por que fazer essa análise:

# Criar um DataFrame com o número de ocorrências por nível de tensão
df_nivel_tensao = df_analise.groupby('NumNivelTensao')['NumNivelTensao'].count().to_frame('Ocorrencias').reset_index()

# Plotar o gráfico
sns.set_theme(style="whitegrid")
plt.figure(figsize=(10, 7))
ax = sns.barplot(x="NumNivelTensao", y="Ocorrencias", data=df_nivel_tensao)
ax.set_title("Número de ocorrências por nível de tensão", fontsize=16)
ax.set_xlabel("Nível de tensão", fontsize=14)
ax.set_ylabel("Ocorrências", fontsize=14)
for p in ax.patches:
    ax.annotate(text = p.get_height(), 
                xy = (p.get_x() + p.get_width() / 2, p.get_height()),
                ha='center',
                va='center',
                size=10,
                xytext=(0, 6),
                textcoords='offset points')
plt.show()

# %%
# 2. Quantidade de ocorrências por tipo de interrupção
# Descrição do por que fazer essa análise:

# Criar um DataFrame com o número de ocorrências por tipo de interrupção
df_interrupcao_tipo = df_analise.groupby(['DscInterrupcaoTipo'])['DscInterrupcaoTipo'].count().to_frame('Ocorrencias').reset_index()

# Plotar o gráfico
sns.set_theme(style="whitegrid")
plt.figure(figsize=(10, 7))
ax = sns.barplot(x="DscInterrupcaoTipo", y="Ocorrencias", data=df_interrupcao_tipo)
ax.set_title("Número de ocorrências por tipo de interrupção", fontsize=16)
ax.set_xlabel("Tipo de interrupção", fontsize=14)
ax.set_ylabel("Ocorrências", fontsize=14)
for p in ax.patches:
    ax.annotate(text = p.get_height(), 
                xy = (p.get_x() + p.get_width() / 2, p.get_height()),
                ha='center',
                va='center',
                size=10,
                xytext=(0, 6),
                textcoords='offset points')
plt.show()

# %%
# 3. Gráfico de Pareto considerando os valores em DscInterrupcaoCausa
# Descrição do por que fazer essa análise:


# Criar um DataFrame com o número de ocorrências por causa de interrupção
df_interrupcao_causa = df_analise.groupby('DscInterrupcaoCausa')['DscInterrupcaoCausa'].count().to_frame('Ocorrencias').reset_index()

# Ordenar o DataFrame por Ocorrencias em ordem decrescente
df_interrupcao_causa = df_interrupcao_causa.sort_values(by='Ocorrencias', ascending=False)

# Calcular a porcentagem de ocorrências
df_interrupcao_causa['Percentual'] = df_interrupcao_causa['Ocorrencias'] / df_interrupcao_causa['Ocorrencias'].sum() * 100

# Calcular a porcentagem acumulada
df_interrupcao_causa['PercentualAcumulado'] = df_interrupcao_causa['Percentual'].cumsum()

# Plotar o gráfico
sns.set_theme(style="whitegrid")
plt.figure(figsize=(20, 10))
ax = sns.barplot(x="DscInterrupcaoCausa", y="Ocorrencias", data=df_interrupcao_causa)
ax.set_title("Número de ocorrências por causa de interrupção", fontsize=16)
ax.set_xlabel("Causa de interrupção", fontsize=14)
ax.set_ylabel("Ocorrências", fontsize=14)

# Eixo secundário
ax2 = ax.twinx()

# Cria a Curva de Pareto no eixo secundário
ax2.plot(df_interrupcao_causa["DscInterrupcaoCausa"], df_interrupcao_causa["PercentualAcumulado"], color="red", marker="D", ms=7, label='Pareto')

# Configurações dos eixos
ax.tick_params(axis="y", colors="C0")
ax2.tick_params(axis="y", colors="C1")
ax2.set_ylim([0,110])

# Ajusta a inclinação dos labels do eixo x
for tick in ax.get_xticklabels():
    tick.set_rotation(45)
    
# Finalmente mostra o grafico definido acima
plt.legend() # para mostrar a legenda
plt.show()

# %%
# 4. Tabela de frequência Causa x Descrição
# Descrição do por que fazer essa análise:

# Criar um DataFrame com o número de ocorrências por causa e descrição de interrupção
df_causa_descricao = df_analise.groupby(['DscInterrupcaoCausa', 'DscInterrupcaoDescricao'])['DscInterrupcaoDescricao'].count().to_frame('Ocorrencias').reset_index()

# Ordenar o DataFrame por Ocorrencias em ordem decrescente
df_causa_descricao = df_causa_descricao.sort_values(by='Ocorrencias', ascending=False)

df_causa_descricao
# Out:
#     DscInterrupcaoCausa                            DscInterrupcaoDescricao  \
# 10     Nao Classificada                                   Nao Classificada
# 6         Meio Ambiente                                Arvore ou Vegetacao
# 12  Proprias do Sistema                   Falha de material ou equipamento
# 13  Proprias do Sistema                                   Nao identificada
# 5         Meio Ambiente                                            Animais
# 9         Meio Ambiente                                              Vento
# 0             Alteracao                                     Para Ampliacao
# 7         Meio Ambiente                               Descarga Atmosferica
# 1             Alteracao                                      Para Melhoria
# 14  Proprias do Sistema                                         Sobrecarga
# 4            Manutencao                                         Preventiva
# 19            Terceiros                                     Objeto na Rede
# 16            Terceiros                                       Abalroamento
# 3            Manutencao                                          Corretiva
# 20            Terceiros                                              Roubo
# 18            Terceiros  Defeito interno nao afetando outras unidades c...
# 15  Proprias do Sistema                                          Subtensao
# 11  Proprias do Sistema           Desligamento para manutencao emergencial
# 2     Falha Operacional                                   Erro de Operacao
# 8         Meio Ambiente                                           Poluicao
# 17            Terceiros                    Defeito Cliente Afetando Outros
#
#     Ocorrencias
# 10        29401
# 6         17972
# 12        17775
# 13        11944
# 5         10399
# 9          9013
# 0          5924
# 7          5028
# 1          4877
# 14         4072
# 4          3790
# 19         3414
# 16         3210
# 3          2080
# 20         1925
# 18         1395
# 15          826
# 11          122
# 2           118
# 8            40
# 17           10

# %%
# Usar o método pivot para criar uma tabela de frequência com os dados do df_causa_descricao

# Criar o pivot
df_causa_descricao_pivot = df_causa_descricao.pivot(index='DscInterrupcaoDescricao', columns='DscInterrupcaoCausa', values='Ocorrencias')

# Ordenar as colunas em ordem decrescente
df_causa_descricao_pivot = df_causa_descricao_pivot.reindex(df_causa_descricao_pivot.sum().sort_values(ascending=False).index, axis=1)

# Ordenar as linhas em ordem decrescente
df_causa_descricao_pivot = df_causa_descricao_pivot.reindex(df_causa_descricao_pivot.sum(axis=1).sort_values(ascending=False).index)

# Filtrar os valores nulos e substituir por 0
df_causa_descricao_pivot = df_causa_descricao_pivot.fillna(0)

# Mostrar a tabela de frequência com mapas de calor
sns.set_theme(style="whitegrid")
plt.figure(figsize=(20, 10))
ax = sns.heatmap(df_causa_descricao_pivot, annot=True, fmt=".0f", cmap="Blues")

plt.show()

# %%
# 5. Tabela de frequências Tipo x Descrição
# Descrição do por que fazer essa análise:

# Criar um DataFrame com o número de ocorrências por tipo e descrição de interrupção
df_tipo_descricao = df_analise.groupby(['DscInterrupcaoTipo', 'DscInterrupcaoDescricao'])['DscInterrupcaoDescricao'].count().to_frame('Ocorrencias').reset_index()

# Ordenar o DataFrame por tipo e depois por Ocorrencias em ordem decrescente
df_tipo_descricao = df_tipo_descricao.sort_values(by=['DscInterrupcaoTipo', 'Ocorrencias'], ascending=[True, False])

df_tipo_descricao
# Out:
#    DscInterrupcaoTipo                            DscInterrupcaoDescricao  \
# 9      Nao Programada                                   Nao Classificada
# 2      Nao Programada                                Arvore ou Vegetacao
# 8      Nao Programada                   Falha de material ou equipamento
# 10     Nao Programada                                   Nao identificada
# 1      Nao Programada                                            Animais
# 16     Nao Programada                                              Vento
# 5      Nao Programada                               Descarga Atmosferica
# 14     Nao Programada                                         Sobrecarga
# 11     Nao Programada                                     Objeto na Rede
# 0      Nao Programada                                       Abalroamento
# 13     Nao Programada                                              Roubo
# 4      Nao Programada  Defeito interno nao afetando outras unidades c...
# 15     Nao Programada                                          Subtensao
# 6      Nao Programada           Desligamento para manutencao emergencial
# 7      Nao Programada                                   Erro de Operacao
# 12     Nao Programada                                           Poluicao
# 3      Nao Programada                    Defeito Cliente Afetando Outros
# 19         Programada                                     Para Ampliacao
# 20         Programada                                      Para Melhoria
# 21         Programada                                         Preventiva
# 17         Programada                                          Corretiva
# 18         Programada                                   Nao Classificada
#
#     Ocorrencias
# 9         29394
# 2         17972
# 8         17775
# 10        11944
# 1         10399
# 16         9013
# 5          5028
# 14         4072
# 11         3414
# 0          3210
# 13         1925
# 4          1395
# 15          826
# 6           122
# 7           118
# 12           40
# 3            10
# 19         5924
# 20         4877
# 21         3790
# 17         2080
# 18            7

# %%
# Criar um grafico de barras horizontal para df_tipo_descricao
sns.set_theme(style="whitegrid")
plt.figure(figsize=(20, 10))
ax = sns.barplot(x="Ocorrencias", y="DscInterrupcaoDescricao", hue="DscInterrupcaoTipo", data=df_tipo_descricao)
ax.set_title("Número de ocorrências por tipo e descrição de interrupção", fontsize=16)
ax.set_xlabel("Ocorrências", fontsize=14)
ax.set_ylabel("Descrição de interrupção", fontsize=14)
plt.show()

# %%
# 6. Gráfico com a quantidade de ocorrências por semana e fim de semana e feriado (False = dia normal e True = feriado)
# Descrição do por que fazer essa análise:

# Criar um DataFrame com o número de ocorrências por semana e fim de semana e feriado
df_semana_feriado = df_analise.groupby(['DatSemana', 'DatFeriado'])['DatFeriado'].count().to_frame('Ocorrencias').reset_index()

# Plotar o gráfico
sns.set_theme(style="whitegrid")
plt.figure(figsize=(10, 7))
ax = sns.barplot(x="DatSemana", y="Ocorrencias", hue="DatFeriado", data=df_semana_feriado)
ax.set_title("Número de ocorrências por semana e fim de semana e feriado", fontsize=16)
ax.set_xlabel("Semana", fontsize=14)
ax.set_ylabel("Ocorrências", fontsize=14)
for p in ax.patches:
    ax.annotate(text = p.get_height(), 
                xy = (p.get_x() + p.get_width() / 2, p.get_height()),
                ha='center',
                va='center',
                size=10,
                xytext=(0, 6),
                textcoords='offset points')
plt.show()

# %%
# 3. Duração das Interrupções:
#     - Calcular a duração média das interrupções e identificar as de maior impacto.

# Criar um DataFrame com a duração média das interrupções por tipo e causa de interrupção
df_duracao_media = df_analise.groupby(['DscInterrupcaoTipo', 'DscInterrupcaoCausa'])['TempoTotalInterrupcao'].mean().to_frame('DuracaoMedia').reset_index()

# Ordenar o DataFrame por tipo e depois por DuracaoMedia em ordem decrescente
df_duracao_media = df_duracao_media.sort_values(by=['DscInterrupcaoTipo', 'DuracaoMedia'], ascending=[True, False])

# Mostrar o DataFrame
df_duracao_media
# Out:
#   DscInterrupcaoTipo  DscInterrupcaoCausa  DuracaoMedia
# 1     Nao Programada        Meio Ambiente    293.570173
# 4     Nao Programada            Terceiros    180.778481
# 3     Nao Programada  Proprias do Sistema    173.464320
# 2     Nao Programada     Nao Classificada    152.025481
# 0     Nao Programada    Falha Operacional    106.796610
# 7         Programada     Nao Classificada    221.714286
# 5         Programada            Alteracao    154.701417
# 6         Programada           Manutencao    153.324361

# %%
# Plotar o gráfico
sns.set_theme(style="whitegrid")
plt.figure(figsize=(20, 10))
ax = sns.barplot(x="DuracaoMedia", y="DscInterrupcaoCausa", hue="DscInterrupcaoTipo", data=df_duracao_media)
ax.set_title("Duração média das interrupções por tipo e causa de interrupção", fontsize=16)
ax.set_xlabel("Duração média", fontsize=14)
ax.set_ylabel("Causa de interrupção", fontsize=14)
plt.show()

# %%
def intervalo(tempo):
    if(tempo <59):
        return "Menos de 1 hora"
    elif(tempo >=60 and tempo <239):
        return "Entre 1 e 4 horas"
    elif(tempo >=239.0 and tempo <1439.0):
        return "Entre 4 horas e 1 dia"
    elif(tempo >=1439.0 and tempo <10079.0):
        return "Entre 1 dia e 1 semana"
    else:
        return "Mais de 1 semana"
    
df_analise['Intervalo'] = df_analise['TempoTotalInterrupcao'].apply(intervalo)
lista_intervalo = df_analise['Intervalo'].unique()

# %%
# Plotar o gráfico de Período de Interrupção (Intervalo x Ocorrências)
# Em ordem decrescente

# Criar um DataFrame com o número de ocorrências por intervalo
df_intervalo = df_analise.groupby('Intervalo')['Intervalo'].count().to_frame('Ocorrencias').reset_index()

# Ordenar o DataFrame por Ocorrencias em ordem decrescente
df_intervalo = df_intervalo.sort_values(by='Ocorrencias', ascending=False)

# Plotar o gráfico
fig, ax = plt.subplots(figsize=(20, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(x="Intervalo", y="Ocorrencias", data=df_intervalo)
ax.set_title("Número de ocorrências por intervalo", fontsize=16)
ax.set_xlabel("Intervalo", fontsize=14)
ax.set_ylabel("Ocorrências", fontsize=14)
for p in ax.patches:
    ax.annotate(text = p.get_height(), 
                xy = (p.get_x() + p.get_width() / 2, p.get_height()),
                ha='center',
                va='center',
                size=10,
                xytext=(0, 6),
                textcoords='offset points')
plt.show()

# %%
# Plotar o gráfico de Período de Interrupção por descrição e causa de interrupção
# Em ordem decrescente

# Criar um DataFrame com o número de ocorrências por intervalo, descrição e causa de interrupção
df_intervalo_descricao_causa = df_analise.groupby(['Intervalo', 'DscInterrupcaoDescricao', 'DscInterrupcaoCausa'])['Intervalo'].count().to_frame('Ocorrencias').reset_index()

# Ordenar o DataFrame por Ocorrencias em ordem decrescente
df_intervalo_descricao_causa = df_intervalo_descricao_causa.sort_values(by='Ocorrencias', ascending=False)

# Plotar o gráfico
fig, ax = plt.subplots(figsize=(20, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(x="Intervalo", y="Ocorrencias", hue="DscInterrupcaoDescricao", data=df_intervalo_descricao_causa)
ax.set_title("Número de ocorrências por intervalo, descrição e causa de interrupção", fontsize=16)
ax.set_xlabel("Intervalo", fontsize=14)
ax.set_ylabel("Ocorrências", fontsize=14)
for p in ax.patches:
    ax.annotate(text = p.get_height(), 
                xy = (p.get_x() + p.get_width() / 2, p.get_height()),
                ha='center',
                va='center',
                size=10,
                xytext=(0, 6),
                textcoords='offset points') 
plt.show()

# %% [markdown]
# #### 4. Com o conjunto de dados do item 3 aplique algum algoritmo de aprendizado de máquina, apresente e discuta os resultados obtidos. Talvez seja necessário realizar transformações para que os dados esteja adequado ao algoritmo escolhido.

# %%
# Excluir colunas que são redundantes para o modelo de regressão linear
df_analise.drop(['DscConjuntoUnidadeConsumidora', 'DscAlimentadorSubestacao', 'DscSubestacaoDistribuicao', 'DatInicioInterrupcao', 'DatFimInterrupcao', 'NumConsumidorConjunto', 'SigAgente', 'TempoTotalInterrupcao'], axis=1, inplace=True)

df_analise.head()
# Out:
#    IdeMotivoInterrupcao  NumNivelTensao  NumUnidadeConsumidora  \
# 0                     0             220                     94
# 1                     0             220                      1
# 2                     0             220                      1
# 3                     0             220                      1
# 4                     0           23000                     43
#
#   DscInterrupcaoOrigem DscInterrupcaoTipo  DscInterrupcaoCausa  \
# 0              Interna     Nao Programada  Proprias do Sistema
# 1              Interna     Nao Programada     Nao Classificada
# 2              Interna     Nao Programada     Nao Classificada
# 3              Interna     Nao Programada     Nao Classificada
# 4              Interna     Nao Programada     Nao Classificada
#
#   DscInterrupcaoDescricao      DatSemana  DatFeriado              Intervalo
# 0              Sobrecarga  Dia de semana       False      Entre 1 e 4 horas
# 1        Nao Classificada  Dia de semana       False      Entre 1 e 4 horas
# 2        Nao Classificada  Dia de semana       False      Entre 1 e 4 horas
# 3        Nao Classificada  Dia de semana       False      Entre 1 e 4 horas
# 4        Nao Classificada  Dia de semana       False  Entre 4 horas e 1 dia

# %%
# Transformar as colunas categóricas em numéricas
le = LabelEncoder()

df_analise['DscInterrupcaoOrigem'] = le.fit_transform(df_analise['DscInterrupcaoOrigem'])
df_analise['DscInterrupcaoTipo'] = le.fit_transform(df_analise['DscInterrupcaoTipo'])
df_analise['DscInterrupcaoCausa'] = le.fit_transform(df_analise['DscInterrupcaoCausa'])
df_analise['DscInterrupcaoDescricao'] = le.fit_transform(df_analise['DscInterrupcaoDescricao'])
df_analise['DatSemana'] = le.fit_transform(df_analise['DatSemana'])
df_analise['DatFeriado'] = le.fit_transform(df_analise['DatFeriado'])
df_analise['Intervalo'] = le.fit_transform(df_analise['Intervalo'])

df_analise.head()
# Out:
#    IdeMotivoInterrupcao  NumNivelTensao  NumUnidadeConsumidora  \
# 0                     0             220                     94
# 1                     0             220                      1
# 2                     0             220                      1
# 3                     0             220                      1
# 4                     0           23000                     43
#
#    DscInterrupcaoOrigem  DscInterrupcaoTipo  DscInterrupcaoCausa  \
# 0                     1                   0                    5
# 1                     1                   0                    4
# 2                     1                   0                    4
# 3                     1                   0                    4
# 4                     1                   0                    4
#
#    DscInterrupcaoDescricao  DatSemana  DatFeriado  Intervalo
# 0                       18          0           0          1
# 1                       10          0           0          1
# 2                       10          0           0          1
# 3                       10          0           0          1
# 4                       10          0           0          2

# %%
corr = df_analise.corr()
corr
# Out:
#                          IdeMotivoInterrupcao  NumNivelTensao  \
# IdeMotivoInterrupcao                 1.000000        0.141094
# NumNivelTensao                       0.141094        1.000000
# NumUnidadeConsumidora                0.071707        0.181890
# DscInterrupcaoOrigem                -0.157143       -0.033909
# DscInterrupcaoTipo                  -0.115512       -0.103699
# DscInterrupcaoCausa                 -0.041908       -0.068501
# DscInterrupcaoDescricao              0.067317       -0.165315
# DatSemana                           -0.077550        0.006185
# DatFeriado                          -0.033405       -0.000035
# Intervalo                           -0.014950        0.061186
#
#                          NumUnidadeConsumidora  DscInterrupcaoOrigem  \
# IdeMotivoInterrupcao                  0.071707             -0.157143
# NumNivelTensao                        0.181890             -0.033909
# NumUnidadeConsumidora                 1.000000             -0.150285
# DscInterrupcaoOrigem                 -0.150285              1.000000
# DscInterrupcaoTipo                   -0.024759              0.009580
# DscInterrupcaoCausa                   0.044056             -0.007918
# DscInterrupcaoDescricao               0.026426             -0.005330
# DatSemana                             0.004732              0.018247
# DatFeriado                           -0.002531              0.003931
# Intervalo                             0.216589             -0.057363
#
#                          DscInterrupcaoTipo  DscInterrupcaoCausa  \
# IdeMotivoInterrupcao              -0.115512            -0.041908
# NumNivelTensao                    -0.103699            -0.068501
# NumUnidadeConsumidora             -0.024759             0.044056
# DscInterrupcaoOrigem               0.009580            -0.007918
# DscInterrupcaoTipo                 1.000000            -0.748407
# DscInterrupcaoCausa               -0.748407             1.000000
# DscInterrupcaoDescricao            0.241072            -0.032549
# DatSemana                         -0.064092             0.049989
# DatFeriado                        -0.031634             0.031439
# Intervalo                         -0.051399             0.107818
#
#                          DscInterrupcaoDescricao  DatSemana  DatFeriado  \
# IdeMotivoInterrupcao                    0.067317  -0.077550   -0.033405
# NumNivelTensao                         -0.165315   0.006185   -0.000035
# NumUnidadeConsumidora                   0.026426   0.004732   -0.002531
# DscInterrupcaoOrigem                   -0.005330   0.018247    0.003931
# DscInterrupcaoTipo                      0.241072  -0.064092   -0.031634
# DscInterrupcaoCausa                    -0.032549   0.049989    0.031439
# DscInterrupcaoDescricao                 1.000000  -0.048043   -0.017275
# DatSemana                              -0.048043   1.000000   -0.006239
# DatFeriado                             -0.017275  -0.006239    1.000000
# Intervalo                               0.045789   0.034702    0.010269
#
#                          Intervalo
# IdeMotivoInterrupcao     -0.014950
# NumNivelTensao            0.061186
# NumUnidadeConsumidora     0.216589
# DscInterrupcaoOrigem     -0.057363
# DscInterrupcaoTipo       -0.051399
# DscInterrupcaoCausa       0.107818
# DscInterrupcaoDescricao   0.045789
# DatSemana                 0.034702
# DatFeriado                0.010269
# Intervalo                 1.000000

# %%
# Plotar a matriz de correlação
f, ax = plt.subplots(figsize=(20, 10))
sns.heatmap(corr, annot=True, fmt=".2f", cmap="Blues")
plt.show()

# %%
# Separar os dados em X e y
X = df_analise.drop('Intervalo', axis=1)
y = df_analise['Intervalo']

# %%
# Separar os dados em treino e teste (80% treino e 20% teste)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.8)

# Criar o modelo de regressão linear
regressor = LinearRegression()

# Treinar o modelo
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Verificar o resultado do treino (Coeficiente de determinação R²)
r_sq = regressor.score(X_train, y_train)
print(f"Coeficiente de determinação R²: {r_sq}")
# Out:
# Coeficiente de determinação R²: 0.06685774682730417
